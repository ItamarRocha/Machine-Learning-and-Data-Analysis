# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("students.csv")

# %%
df.head()
# Out:
#             Timestamp                            Nome Completo Assessor Idade  \
# 0                 NaN                                      NaN      NaN   NaN
# 1  6/16/2020 23:06:19            Gonzalo Alonso Medeiros Bueno   Itamar    18
# 2  6/16/2020 23:31:55                            Lara Pereira    Rayssa    17
# 3  6/16/2020 23:33:30        Lucca Nuto França De Albuquerque    Rayssa    16
# 4  6/16/2020 23:40:36  Sophia Adelino Xavier Pontes de Freitas  Rodrigo    18
#
#       Gênero  Quão compatível com seu assessor você se considera?  \
# 0        NaN                                                NaN
# 1  Masculino                                               10.0
# 2   Feminino                                                8.0
# 3  Masculino                                               10.0
# 4   Feminino                                                7.0
#
#   Onde fez/faz ensino médio? Alguma religião? Gosta de esportes?  \
# ...

# %%
df = df.drop(index = 0)

# %%
df[df['Assessor'] == 'Carolzinha']['Nome Completo']
# Out:
# 80           Gabriella Gomes Ferreira gadelha
# 81              maria eduarda sarmento lucena
# 82               Anne Gabrielle de Sousa Diniz
# 86     Camilla Ellen Crispim de Felix Nobrega
# 88          Myllena Enmyly Ferreira de Almeida
# 89                               Beatriz Diniz
# 94                            Manuella Freire
# 96          Ana Karenina Barreto Amorim Pessoa
# 117                      Vitória Gouveia Gomes
# 129                  Camilla Queiroz Ferreira
# 137    Rafaela Maria Ribera Gonçalves de Souza
# 141                    Alice de Oliveira Maia
# Name: Nome Completo, dtype: object

# %%
df.Assessor.value_counts()
# Out:
# Davi              15
# Débora            15
# Gelielison        15
# Itamar            14
# Patriota          12
# Carolzinha        12
# Glaucielle        12
# Lorena            10
# Mateus Tavares     9
# Eduardo            9
# Ariel              8
# Rodrigo            8
# Catharina          7
# Rayssa             7
# Fabiana            4
# Lucas              1
# Name: Assessor, dtype: int64

# %%
df.describe()
# Out:
#        Quão compatível com seu assessor você se considera?  \
# count                                         158.000000
# mean                                            9.139241
# std                                             1.091183
# min                                             5.000000
# 25%                                             9.000000
# 50%                                             9.000000
# 75%                                            10.000000
# max                                            10.000000
#
#        Como foi/está sendo a qualidade de seu ensino médio?  \
# count                                         158.000000
# mean                                            3.696203
# std                                             0.935560
# min                                             0.000000
# 25%                                             3.000000
# 50%                                             4.000000
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Nome Completo', 'Assessor', 'Idade', 'Gênero',
#        'Quão compatível com seu assessor você se considera?',
#        'Onde fez/faz ensino médio?', 'Alguma religião?', 'Gosta de esportes?',
#        'Como foi/está sendo a qualidade de seu ensino médio?',
#        'Você se envolve com política?', 'Como se considera politicamente?',
#        'Que área compreende o curso que deseja fazer na faculdade?',
#        'Qual sua área preferida no ENEM?', 'Quantos irmãos você tem?',
#        'Tem ou já teve algum problema de saúde físico?',
#        'Tem ou já teve algum problema de saúde mental?',
#        'Pretende fazer faculdade na paraíba?',
#        'Pratica atividade física com frequência?',
#        'Introvertido ou extrovertido?', 'No tempo livre prefere:',
#        'Tem facilidade em fazer amizades?',
#        'Que tipo de assessor prefere? mais técnico ou que lide melhor com seu emocional?',
#        'Quantas vezes já fez enem? (sem contar como treineiro)',
# ...
