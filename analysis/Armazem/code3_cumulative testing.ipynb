# %% [markdown]
# * O objetivo desse notebook é fazer um forecasting com os dados acumulados e depois revertes esses dados para o normal. Não acho que essa técnica vale a pena.

# %%
import pandas as pd
import numpy as np
from fbprophet import Prophet
import matplotlib.pyplot as plt

# %%
frequent_products = pd.read_csv("frequent.csv", index_col=0)

# %%
frequent_products.head()
# Out:
#             ENTREGA  GE2 CELULAR  GE1 ELETROPORTATEIS  GE1 CELULAR  \
# 2015-01-02     22.0         11.0                 11.0         22.0
# 2015-01-03     31.0         12.0                 24.0         26.0
# 2015-01-05     41.0          8.0                 26.0         28.0
# 2015-01-06     44.0         10.0                 22.0         23.0
# 2015-01-07     55.0          9.0                 21.0         38.0
#
#             CHIP VIVO 4G 128K P19 HRS PRE  GE1 TV LCD LED  \
# 2015-01-02                           17.0             4.0
# 2015-01-03                           20.0             4.0
# 2015-01-05                           19.0             4.0
# 2015-01-06                           20.0             4.0
# 2015-01-07                           22.0             5.0
#
#             CHIP CLARO ODA 128KB TRIPE  GE1 MOVEIS 1  GE2 REFRIGERADOR  \
# 2015-01-02                         0.0           2.0               3.0
# 2015-01-03                         0.0           4.0               2.0
# 2015-01-05                         0.0           8.0              20.0
# 2015-01-06                         0.0           4.0               7.0
# 2015-01-07                         0.0           7.0               8.0
#
#             CHIP TIM INFINITY PRE HRD TRIPLO 4G  ...  CHIP OI 4G HLR 39  \
# 2015-01-02                                  0.0  ...                0.0
# 2015-01-03                                  0.0  ...                0.0
# 2015-01-05                                  0.0  ...                0.0
# 2015-01-06                                  0.0  ...                0.0
# 2015-01-07                                  0.0  ...                0.0
#
#             GE2 LAV. ROUPAS AUTOMATICA  \
# 2015-01-02                         0.0
# 2015-01-03                         0.0
# 2015-01-05                         2.0
# 2015-01-06                         2.0
# 2015-01-07                         2.0
#
#             SUPORTE TV UNIVERSAL LCD/LED 10 A 71 SBRUB750  \
# 2015-01-02                                            0.0
# 2015-01-03                                            0.0
# 2015-01-05                                            0.0
# 2015-01-06                                            0.0
# 2015-01-07                                            0.0
#
#             VENTILADOR 40CM V-49 6P RED PREMIUM  \
# 2015-01-02                                  0.0
# 2015-01-03                                  0.0
# 2015-01-05                                  0.0
# 2015-01-06                                  0.0
# 2015-01-07                                  0.0
#
#             TABLET NB184 M7S QUAD CORE PRETO  GE1 FOGAO 2 A 6 BOCAS  \
# 2015-01-02                               0.0                    0.0
# 2015-01-03                               0.0                    0.0
# 2015-01-05                               0.0                    1.0
# 2015-01-06                               0.0                    3.0
# 2015-01-07                               0.0                    1.0
#
#             FOGAO 4BC. BALI 4076 BR  VENTILADOR 30CM NV-15 6P BR 220V  \
# 2015-01-02                      0.0                               0.0
# 2015-01-03                      0.0                               0.0
# 2015-01-05                      0.0                               0.0
# 2015-01-06                      0.0                               0.0
# 2015-01-07                      0.0                               0.0
#
#             CELULAR RIU-I R200 DB PRETO-VERMELHO  \
# 2015-01-02                                   0.0
# 2015-01-03                                   0.0
# 2015-01-05                                   0.0
# 2015-01-06                                   0.0
# 2015-01-07                                   0.0
#
#             CELULAR RIU-I R200 DB PRETO-AMARELO
# 2015-01-02                                  0.0
# 2015-01-03                                  0.0
# 2015-01-05                                  0.0
# 2015-01-06                                  0.0
# 2015-01-07                                  0.0
#
# [5 rows x 50 columns]

# %%
ferro = frequent_products["FERRO SECO METALICO VFA 1110X BLACK E DECKER"]
ventilador = frequent_products["VENTILADOR VF40 SILENCE FORCE CD RE"]

# %%
ferro
# Out:
# 2015-01-02    0.0
# 2015-01-03    1.0
# 2015-01-05    2.0
# 2015-01-06    2.0
# 2015-01-07    0.0
#              ...
# 2019-06-19    0.0
# 2019-06-20    1.0
# 2019-06-21    4.0
# 2019-06-22    1.0
# 2019-06-25    0.0
# Name: FERRO SECO METALICO VFA 1110X BLACK E DECKER, Length: 1404, dtype: float64

# %%
cum_ferro = ferro.cumsum()

# %%
cum_ventilador = ventilador.cumsum()

# %%
def reverse_cumsum(series, initial = 0):
    series = series - series.shift(1).replace(np.nan, 0)
    series[0] -= initial
    return series

# %% [markdown]
# ## Testando com Ventilador

# %% [markdown]
# ### Naive Approach

# %%
import baseline_tools
from tensorflow.keras.metrics import mean_absolute_error, mean_squared_error

# %%
cum_ventilador.index = pd.to_datetime(cum_ventilador.index)
train = cum_ventilador.loc[cum_ventilador.index.year != 2019]
test = cum_ventilador.loc[cum_ventilador.index.year == 2019]

# %%
naive, real = baseline_tools.naive_forecast(test)

# %%
plt.figure(figsize=(20,15))
baseline_tools.plot_series(real.index, real, label="real")
baseline_tools.plot_series(real.index, naive, label="naive")
plt.show()

# %%
naive
# Out:
# 2019-01-03    5909.0
# 2019-01-04    5909.0
# 2019-01-05    5909.0
# 2019-01-06    5909.0
# 2019-01-07    5909.0
#                ...
# 2019-06-19    6829.0
# 2019-06-20    6831.0
# 2019-06-21    6832.0
# 2019-06-22    6832.0
# 2019-06-25    6833.0
# Name: VENTILADOR VF40 SILENCE FORCE CD RE, Length: 153, dtype: float64

# %%
real
# Out:
# 2019-01-03    5909.0
# 2019-01-04    5909.0
# 2019-01-05    5909.0
# 2019-01-06    5909.0
# 2019-01-07    5909.0
#                ...
# 2019-06-19    6831.0
# 2019-06-20    6832.0
# 2019-06-21    6832.0
# 2019-06-22    6833.0
# 2019-06-25    6833.0
# Name: VENTILADOR VF40 SILENCE FORCE CD RE, Length: 153, dtype: float64

# %%
real_reversed = reverse_cumsum(real, initial=train[-1]).values

# %%
naive_reversed = reverse_cumsum(naive, initial=test[0]).values

# %%
mean_absolute_error(real_reversed, naive_reversed).numpy()
# Out:
# 3.895424836601307

# %%
mean_squared_error(real_reversed, naive_reversed).numpy()
# Out:
# 45.64705882352941

# %%
plt.figure(figsize=(20,15))
baseline_tools.plot_series(real.index, real_reversed, label="real")
baseline_tools.plot_series(real.index, naive_reversed, label="naive")
plt.show()

# %% [markdown]
# * Of course it gives us the same answer as doing it without cumulative sum hahaha

# %% [markdown]
# ### Prophet

# %%
train.tail()
# Out:
# 2018-12-27    5907.0
# 2018-12-28    5907.0
# 2018-12-29    5909.0
# 2018-12-30    5909.0
# 2018-12-31    5909.0
# Name: VENTILADOR VF40 SILENCE FORCE CD RE, dtype: float64

# %%
test.tail()
# Out:
# 2019-06-19    6831.0
# 2019-06-20    6832.0
# 2019-06-21    6832.0
# 2019-06-22    6833.0
# 2019-06-25    6833.0
# Name: VENTILADOR VF40 SILENCE FORCE CD RE, dtype: float64

# %%
train = train.reset_index()

# %%
train.columns = ["ds", "y"]

# %%
m = Prophet()
m.fit(train)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
test.shape[0]
# Out:
# 154

# %%
idx = pd.date_range("2019-01-02", "2019-06-25")

# %%
test = test.reindex(idx, fill_value="bfill")

# %%
test.shape[0]
# Out:
# 175

# %%
future = m.make_future_dataframe(periods=test.shape[0] + 1)

# %%
future.tail()
# Out:
#              ds
# 1421 2019-06-21
# 1422 2019-06-22
# 1423 2019-06-23
# 1424 2019-06-24
# 1425 2019-06-25

# %%
forecast_result = m.predict(future)

# %%
fig1 = m.plot(forecast_result)

# %%
fig2 = m.plot_components(forecast_result)

# %%
forecast_result.loc[1245:1255]
# Out:
#              ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 1245 2018-12-27  5974.349071  5914.871695  6014.002862  5974.349071
# 1246 2018-12-28  5980.410339  5933.560566  6027.929180  5980.410339
# 1247 2018-12-29  5986.471608  5945.448427  6040.736442  5986.471608
# 1248 2018-12-30  5992.532877  5960.024142  6054.348696  5992.532877
# 1249 2018-12-31  5998.594146  5970.236566  6065.895207  5998.594146
# 1250 2019-01-01  6004.655415  5992.433465  6084.093563  6004.655415
# 1251 2019-01-02  6010.716684  6007.046208  6104.899071  6010.716684
# 1252 2019-01-03  6016.777953  6019.232943  6118.954129  6016.777953
# 1253 2019-01-04  6022.839221  6037.207381  6137.639701  6022.839221
# 1254 2019-01-05  6028.900490  6056.712094  6152.476725  6028.900490
# 1255 2019-01-06  6034.961759  6072.647015  6166.356282  6034.961759
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 1245  5974.349071       -9.968912             -9.968912             -9.968912
# 1246  5980.410339       -1.054454             -1.054454             -1.054454
# 1247  5986.471608        8.218870              8.218870              8.218870
# 1248  5992.532877       15.469049             15.469049             15.469049
# 1249  5998.594146       22.110269             22.110269             22.110269
# 1250  6004.655415       32.121361             32.121361             32.121361
# 1251  6010.716684       41.815787             41.815787             41.815787
# 1252  6016.777953       52.500462             52.500462             52.500462
# 1253  6022.839221       64.549027             64.549027             64.549027
# 1254  6028.900490       75.993256             75.993256             75.993256
# 1255  6034.961759       84.403707             84.403707             84.403707
#
#         weekly  weekly_lower  weekly_upper     yearly  yearly_lower  \
# 1245 -0.821410     -0.821410     -0.821410  -9.147502     -9.147502
# 1246  1.056105      1.056105      1.056105  -2.110559     -2.110559
# 1247  2.466844      2.466844      2.466844   5.752026      5.752026
# 1248  1.131152      1.131152      1.131152  14.337897     14.337897
# 1249 -1.416836     -1.416836     -1.416836  23.527105     23.527105
# 1250 -1.064006     -1.064006     -1.064006  33.185367     33.185367
# 1251 -1.351850     -1.351850     -1.351850  43.167636     43.167636
# 1252 -0.821410     -0.821410     -0.821410  53.321872     53.321872
# 1253  1.056105      1.056105      1.056105  63.492921     63.492921
# 1254  2.466844      2.466844      2.466844  73.526412     73.526412
# 1255  1.131152      1.131152      1.131152  83.272555     83.272555
#
#       yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 1245     -9.147502                   0.0                         0.0
# 1246     -2.110559                   0.0                         0.0
# 1247      5.752026                   0.0                         0.0
# 1248     14.337897                   0.0                         0.0
# 1249     23.527105                   0.0                         0.0
# 1250     33.185367                   0.0                         0.0
# 1251     43.167636                   0.0                         0.0
# 1252     53.321872                   0.0                         0.0
# 1253     63.492921                   0.0                         0.0
# 1254     73.526412                   0.0                         0.0
# 1255     83.272555                   0.0                         0.0
#
#       multiplicative_terms_upper         yhat
# 1245                         0.0  5964.380159
# 1246                         0.0  5979.355886
# 1247                         0.0  5994.690479
# 1248                         0.0  6008.001927
# 1249                         0.0  6020.704415
# 1250                         0.0  6036.776775
# 1251                         0.0  6052.532471
# 1252                         0.0  6069.278415
# 1253                         0.0  6087.388248
# 1254                         0.0  6104.893747
# 1255                         0.0  6119.365466

# %%
prediction = forecast_result[["ds", "yhat"]]

# %%
prediction.index = pd.to_datetime(prediction.ds)

# %%
prediction.drop(columns=["ds"], inplace=True)
# Out:
# /home/itamar/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
prediction = prediction.loc[prediction.index.year == 2019]

# %%
prediction
# Out:
#                    yhat
# ds
# 2019-01-01  6036.776775
# 2019-01-02  6052.532471
# 2019-01-03  6069.278415
# 2019-01-04  6087.388248
# 2019-01-05  6104.893747
# ...                 ...
# 2019-06-21  7165.253634
# 2019-06-22  7169.055714
# 2019-06-23  7170.261098
# 2019-06-24  7170.406741
# 2019-06-25  7173.602974
#
# [176 rows x 1 columns]

# %%
test.dropna(inplace=True)

# %%
test
# Out:
# 2019-01-02    5909.0
# 2019-01-03    5909.0
# 2019-01-04    5909.0
# 2019-01-05    5909.0
# 2019-01-06    5909.0
#                ...
# 2019-06-19    6831.0
# 2019-06-20    6832.0
# 2019-06-21    6832.0
# 2019-06-22    6833.0
# 2019-06-25    6833.0
# Name: VENTILADOR VF40 SILENCE FORCE CD RE, Length: 154, dtype: float64

# %%
prediction = prediction.loc[test.index]

# %%
prediction
# Out:
#                    yhat
# 2019-01-02  6052.532471
# 2019-01-03  6069.278415
# 2019-01-04  6087.388248
# 2019-01-05  6104.893747
# 2019-01-06  6119.365466
# ...                 ...
# 2019-06-19  7158.473082
# 2019-06-20  7161.126092
# 2019-06-21  7165.253634
# 2019-06-22  7169.055714
# 2019-06-25  7173.602974
#
# [154 rows x 1 columns]

# %%
test_reversed = reverse_cumsum(test, initial=train["y"][-1:])

# %%
prediction_reversed = reverse_cumsum(prediction["yhat"], initial=forecast_result.loc[1250]["yhat"])

# %%
test_reversed
# Out:
# 2019-01-02    0.0
# 2019-01-03    0.0
# 2019-01-04    0.0
# 2019-01-05    0.0
# 2019-01-06    0.0
#              ...
# 2019-06-19    2.0
# 2019-06-20    1.0
# 2019-06-21    0.0
# 2019-06-22    1.0
# 2019-06-25    0.0
# Name: VENTILADOR VF40 SILENCE FORCE CD RE, Length: 154, dtype: float64

# %%
prediction_reversed
# Out:
# 2019-01-02    15.755695
# 2019-01-03    16.745944
# 2019-01-04    18.109833
# 2019-01-05    17.505498
# 2019-01-06    14.471720
#                 ...
# 2019-06-19     1.726232
# 2019-06-20     2.653010
# 2019-06-21     4.127542
# 2019-06-22     3.802080
# 2019-06-25     4.547259
# Name: yhat, Length: 154, dtype: float64

# %%
mean_absolute_error(test_reversed, prediction_reversed).numpy()
# Out:
# 6.158695707434145

# %%
mean_squared_error(test_reversed, prediction_reversed).numpy()
# Out:
# 66.58591878422189

# %%
plt.figure(figsize=(20,15))
baseline_tools.plot_series(test_reversed.index, test_reversed, label="test set")
baseline_tools.plot_series(test_reversed.index, prediction_reversed, label="predicted Prophet")
plt.show()
